# %% [markdown]
# # Demo — Part 3: Audit (provenance)
#
# Worked example of the full agent loop, showing the audit trail behind a risk claim.

# %%
from src.agent.risk_agent import answer, format_answer

a = answer("How risky is AAPL compared to other stocks in its sector?")
print(format_answer(a))

# %%
# Inspect the raw provenance for a specific RiskScore node
a["audit_trail"]
