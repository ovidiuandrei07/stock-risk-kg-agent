# %% [markdown]
# # Demo — Part 2: Query (text2cypher)
#
# Worked example of asking the graph a question in plain language.

# %%
from src.query.text2cypher import ask

result = ask("Which stocks are most correlated with NVDA?")
print(result["cypher"])
result["results"]

# %%
result2 = ask("List stocks with a high risk level, most recent score only.")
print(result2["cypher"])
result2["results"]
